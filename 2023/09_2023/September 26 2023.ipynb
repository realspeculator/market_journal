# %%
from IPython.display import Image

# %% [markdown]
# # September 26, 2023

# %% [markdown]
# Yesterday we saw some bounce back from the low of 4338 on the S&P 500 Futures and 14783 on the Nasdaq Futures. This resulted in a hammer formation at the support level. We have so far seen a 6-8% pullback on the major indexes. Lets see the longterm charts for both the indexes

# %%
Image("https://s3.tradingview.com/snapshots/f/F2QbukWI.png")

# %%
Image("https://s3.tradingview.com/snapshots/z/zETKH7CJ.png")

# %% [markdown]
# When we zoom into the 60 mins chart we see that markets are balancing at the low end of this range and finding value there.

# %%
Image("../../img/2023/09_2023/Screen Shot 2023-09-26 at 9.04.43 AM.png")

# %%
Image("../../img/2023/09_2023/Screen Shot 2023-09-26 at 9.09.27 AM.png")

# %% [markdown]
# ### Where to focus today

# %% [markdown]
# - Watch where the markets open. Is it within yesterdays range or outside.
# - Watch how the markets react when they test the highs and lows of yesterday.
# - Does Apple hold the 172-175 low?
# - Does MSFT hold the 310-315 low?
# - Does AMZN hold the 126 low?
