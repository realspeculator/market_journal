# %%
from IPython.display import Image
import pandas as pd

# %%
Image("../../img/2023/09_2023/Screen Shot 2023-09-25 at 10.52.12 AM.png")

# %% [markdown]
# After a big rally in 2023, the Nasdaq is consolidating roughly in the range between 14750 and 16200. As of September 25, 2023 we are testing the low end of this range.

# %% [markdown]
# Update 11:18 AM.
#
# We could potentially see a rally today in the Nasdaq futures which could test the Friday (Sept 22, 23) high of 15027.

# %%
Image("../../img/2023/09_2023/Screen Shot 2023-09-25 at 11.23.45 AM.png")

# %% [markdown]
# ### Update 1:33 pm
#
# We saw some sellers come in at 12:00pm mark. But we are still trading within the September 22, 2023 range.

# %%
Image("../../img/2023/09_2023/Screen Shot 2023-09-25 at 1.33.17 PM.png")
